# %% [markdown]
# # A.10 Objective declarations

# %%
# install dependencies
# %pip install -q amplpy

from amplpy import AMPL, ampl_notebook

ampl = ampl_notebook(
    modules=['highs'],  # modules to install
    license_uuid='default',  # license to use
)  # instantiate AMPL object and register magics

# %% [markdown]
# The declaration of an objective is one of

# %% [markdown]
# ```ampl
# ob j ective declaration:
#        maximize name alias opt indexing opt [ : expression ] [ suffix - initializations ] ;
#        minimize name alias opt indexing opt [ : expression ] [ suffix - initializations ] ;
# ```

# %% [markdown]
# and may specify an expression in one of the following forms:

# %% [markdown]
# ```ampl
# expression:
#      expr
#      to_come + expr
#      expr + to_come
#      to_come
# ```

# %% [markdown]
# The to_come forms permit columnwise coefficient generation, as for constraints (A.9). Specifying
# none of the above expressions is the same as specifying ": to_come". Suffix-initializations
# may appear as in constraint declarations.
#
# If there are multiple objectives, the one sent to a solver can be set by the objective command;
# see section A.18.6. By default, all objectives are sent.
