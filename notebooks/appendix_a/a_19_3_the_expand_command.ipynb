# %% [markdown]
# # A.19.3 The expand command

# %%
# install dependencies
# %pip install -q amplpy

from amplpy import AMPL, ampl_notebook

ampl = ampl_notebook(
    modules=['highs'],  # modules to install
    license_uuid='default',  # license to use
)  # instantiate AMPL object and register magics

# %% [markdown]
# The expand command prints generated constraints and objectives:

# %% [markdown]
# ```ampl
# expand indexing opt itemlist redirection opt ;
# ```

# %% [markdown]
# The itemlist can assume the same forms allowed in problem declarations. If it is empty, all nondropped
# constraints and objectives are expanded. The variant

# %% [markdown]
# ```ampl
# solexpand indexing opt itemlist redirection opt ;
# ```

# %% [markdown]
# shows how constraints and objectives appear to the solver. It omits constraints and variables eliminated
# by presolve unless they are explicitly specified in the itemlist.
#
# Both the expand and solexpand commands permit variables to appear in the itemlist; for
# each, the commands show the linear coefficients of the variable in the relevant (non-dropped and,
# for solexpand, not eliminated by presolve) constraints and objectives, and indicates "+ nonlinear
# " when the variable also participates nonlinearly in a constraint or objective.
#
# The options expand_precision and expand_round control printing of numbers by
# expand. By default they are printed to 6 significant figures.
