# %% [markdown]
# # A.15 Redirection of input and output

# %%
# install dependencies
# %pip install -q amplpy

from amplpy import AMPL, ampl_notebook

ampl = ampl_notebook(
    modules=['highs'],  # modules to install
    license_uuid='default',  # license to use
)  # instantiate AMPL object and register magics

# %% [markdown]
# An optional redirection phrase can be used with a variety of AMPL commands to capture their
# output in a file for subsequent processing. It applies to all forms of display and print and also
# to most other commands that can produce output, such as solve, objective, `fix`, `drop`,
# `restore`, and expand.
#
# A redirection has one of the forms

# %% [markdown]
# ```ampl
# > filename
# >> filename
# < filename (for read command)
# ```

# %% [markdown]
# in which filename may have any of the forms that can appear in data and commands commands
# (A.14). The file is opened the first time a command specifies filename in a redirection; the first
# form of redirection causes the file to be overwritten upon first being opened, while the second form
# causes output to be appended to the current contents. The form < filename is used only for input
# from the read command (A.17). Once open, filename remains open until a `reset` or unless
# explicitly closed by a close command:

# %% [markdown]
# ```ampl
# close filenames opt ;
# ```

# %% [markdown]
# As long as filename remains open, output forms of redirection causes output to be appended to the
# file's current contents. A close command without a filename closes all open files and pipes. A
# close command may specify a comma-separated list of filenames. The variant

# %% [markdown]
# ```ampl
# remove filename ;
# ```

# %% [markdown]
# closes and deletes filename.
