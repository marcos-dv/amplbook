# %% [markdown]
# # A.7.1 Check statements

# %%
# install dependencies
# %pip install -q amplpy

from amplpy import AMPL, ampl_notebook

ampl = ampl_notebook(
    modules=['highs'],  # modules to install
    license_uuid='default',  # license to use
)  # instantiate AMPL object and register magics

# %% [markdown]
# Check statements supply assertions to help verify that correct data have been read or generated;
# they have the syntax

# %% [markdown]
# ```ampl
# check [ indexing opt : ] lexpr ;
# ```

# %% [markdown]
# Each `check` statement is evaluated when one of the commands solve, write, solution, or
# `check` is executed.
