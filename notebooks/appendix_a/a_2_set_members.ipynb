# %% [markdown]
# # A.2 Set members

# %%
# install dependencies
# %pip install -q amplpy

from amplpy import AMPL, ampl_notebook

ampl = ampl_notebook(
    modules=['highs'],  # modules to install
    license_uuid='default',  # license to use
)  # instantiate AMPL object and register magics

# %% [markdown]
# A set contains zero or more elements or members, each of which is an ordered list of one or
# more components. Each member of a set must be distinct. All members must have the same number
# of components; this common number is called the set's dimension.
#
# A literal set is written as a comma-separated list of members, between braces { and }. If the
# set is one-dimensional, the members are simply numeric constants or literal strings, or any expressions
# that evaluate to numbers or strings:

# %% [markdown]
# ```ampl
# {"a","b","c"}
# {1,2,3,4,5,6,7,8,9}
# {t,t+1,t+2}
# ```

# %% [markdown]
# For a multidimensional set, each member must be written as a parenthesized comma-separated list
# of the above:

# %% [markdown]
# ```ampl
# {("a",2),("a",3),("b",5)}
# {(1,2,3),(1,2,4),(1,2,5),(1,3,7),(1,4,6)}
# ```

# %% [markdown]
# The value of a numeric member is the result of rounding its decimal representation to a floatingpoint
# number. Numeric members that appear different but round to the same floating-point number,
# such as 1 and 0.01E2, are considered the same.
