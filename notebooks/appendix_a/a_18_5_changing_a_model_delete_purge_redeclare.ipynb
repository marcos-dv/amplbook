# %% [markdown]
# # A.18.5 Changing a model: delete, purge, redeclare

# %%
# install dependencies
# %pip install -q amplpy

from amplpy import AMPL, ampl_notebook

ampl = ampl_notebook(
    modules=['highs'],  # modules to install
    license_uuid='default',  # license to use
)  # instantiate AMPL object and register magics

# %% [markdown]
# The command

# %% [markdown]
# ```ampl
# delete namelist ;
# ```

# %% [markdown]
# deletes each name in namelist, restoring any previous meaning name had, provided no other entities
# depend on name, i.e., if `xref` name (A.19.2) reports no dependents.
#
# The command

# %% [markdown]
# ```ampl
# purge namelist ;
# ```

# %% [markdown]
# deletes each name and all its direct and indirect dependents.
#
# The statement

# %% [markdown]
# ```ampl
# redeclare entity - declaration ;
# ```

# %% [markdown]
# replaces any existing declaration of the specified entity with the given one, provided either that the
# entity has no dependents, or that the new declaration does not change the character of the entity (its
# kind, such as set or `param`, and its number of subscripts). A `redeclare` can be applied to
# statements beginning with any of the following:

# %% [markdown]
# ```ampl
# arc    function   minimize  param     set         suffix   var
# check  maximize   node      problem   subject to  table
# ```

# %% [markdown]
# Redeclarations that would cause circular dependencies are rejected.
#
# The command

# %% [markdown]
# ```ampl
# delete check n;
# ```

# %% [markdown]
# deletes the nth `check`, while

# %% [markdown]
# ```ampl
# redeclare check n indexing opt : . . . ;
# ```

# %% [markdown]
# redeclares the nth `check`.
